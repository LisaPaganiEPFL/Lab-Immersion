# %%
from numba_code import *
import matplotlib.pyplot as plt
plt.style.use('default')

# %% [markdown]
# ## Test 5, one mutant, 5 deme, K=1000, s=0.001

# %% [markdown]
# ## 100'000 simulations

# %%
#Initial state for the star
in_numbers=np.array([[0.,1000.],[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder=None

# %%
#Migration matrix of the star
migration_matrix=define_star(N_demes,mI,mO, equal_contribution=True)

# %%
#Fixation probability 
nb_sim=100000
star_et, star_ft, star_fp, star_estd, star_fstd, star_estde, star_fstse = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {star_fp}, with \n average extinction time {star_et} with std {star_estd} and std error {star_estde} and \n average fixation time {star_ft} with std {star_fstd} and std error {star_fstse}')
# Out:
# Fixation probability on 100000 simulations is 0.00885, with
#  average extinction time 8.761791857942793 with std 35.212629597544925 and std error 0.11184813985165425 and
#  average fixation time 1873.483615819209 with std 171.74197590044352 and std error 5.773043365670133

# %%
folder='5_wm'

#Migration matrix of the clique
migration_matrix=np.array([[1]])

in_numbers=np.array([[1.,4999.]]).astype(np.int64)

# %%
#Fixation probability 
nb_sim=100000
K=5000
wm_et, wm_ft, wm_fp, wm_estd, wm_fstd, wm_estde, wm_fstse = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {wm_fp}, with \n average extinction time {wm_et} with std {wm_estd} and std error {wm_estde} and \n average fixation time {wm_ft} with std {wm_fstd} and std error {wm_fstse}')
# Out:
# Fixation probability on 100000 simulations is 0.00937, with
#  average extinction time 8.71399008711628 with std 35.890029743900975 and std error 0.11402972587722743 and
#  average fixation time 1884.6627534685165 with std 136.66040647208587 and std error 4.464500877653584

# %%
#Initial state for the star
in_numbers=np.array([[0.,1000.],[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder='5_clique'
migration_matrix=define_clique(N_demes,m)
nb_sim=1

# %%
#Fixation probability 
nb_sim=100000
cl_et, cl_ft, cl_fp, cl_estd, cl_fstd, cl_estde, cl_fstse = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {cl_fp}, with \n average extinction time {cl_et} with std {cl_estd} and std error {cl_estde} and \n average fixation time {cl_ft} with std {cl_fstd} and std error {cl_fstse}')
# Out:
# Fixation probability on 100000 simulations is 0.00907, with
#  average extinction time 8.805384840503365 with std 37.3666900563198 and std error 0.11870339530479594 and
#  average fixation time 1924.5281146637267 with std 189.03668634971385 and std error 6.276860146863689

# %%
params = ['Star', 'Wm', 'Clique']

mean = np.array([star_ft, wm_ft, cl_ft])
error = np.array([star_fstse, wm_fstse, cl_fstse])*1.96


plt.errorbar(mean,np.array(range(len(mean))), xerr=error, linewidth=1, linestyle='none', marker='o', markersize=3, markeredgecolor='black', capsize=5)
#plt.axvline(0, color = 'k', ls = '--')
plt.yticks(range(len(params)), params)
plt.title('Fixation time, 95% confidence intervals')
plt.xlabel('Time')
plt.show()

# %%
params = ['Star', 'Wm', 'Clique']

mean = np.array([star_et, wm_et, cl_et])
error = np.array([star_estde, wm_estde, cl_estde])*1.96


plt.errorbar(mean,np.array(range(len(mean))), xerr=error, linewidth=1, linestyle='none', marker='o', markersize=3, markeredgecolor='black', capsize=5)
#plt.axvline(0, color = 'k', ls = '--')
plt.yticks(range(len(params)), params)
plt.title('Extinction time, 95% confidence intervals')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# ## 1 milion simulations
#
# ### Leaf mutant

# %%
#Initial state for the star
in_numbers=np.array([[0.,1000.],[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder=None

# %%
#Migration matrix of the star
migration_matrix=define_star(N_demes,mI,mO, equal_contribution=True)

# %%
#Fixation probability 
nb_sim=1000000
star_et, star_ft, star_fp, star_estd, star_fstd, star_estde, star_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {star_fp}, with \n average extinction time {star_et} with std {star_estd} and std error {star_estde} and \n average fixation time {star_ft} with std {star_fstd} and std error {star_fstse}')
# Out:
# Fixation probability on 1000000 simulations is 0.009035, with
#  average extinction time 8.900208382738038 with std 36.36817293217773 and std error 0.03653358789430927 and
#  average fixation time 1857.4050913115661 with std 190.91203004522137 and std error 5.773043365670133

# %%
#Migration matrix of the clique
migration_matrix=np.array([[1]])
in_numbers=np.array([[1.,4999.]]).astype(np.int64)

# %%
#Fixation probability 
nb_sim=1000000
K=5000
wm_et, wm_ft, wm_fp, wm_estd, wm_fstd, wm_estde, wm_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {wm_fp}, with \n average extinction time {wm_et} with std {wm_estd} and std error {wm_estde} and \n average fixation time {wm_ft} with std {wm_fstd} and std error {wm_fstse}')
# Out:
# Fixation probability on 1000000 simulations is 0.009415, with
#  average extinction time 8.619522807230071 with std 35.99781903643571 and std error 0.03616848483339814 and
#  average fixation time 1899.9731279872544 with std 181.18680259980383 and std error 4.464500877653584

# %%
in_numbers=np.array([[0.,1000.],[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder='5_clique'
migration_matrix=define_clique(N_demes,m)

# %%
#Fixation probability 
nb_sim=1000000
cl_et, cl_ft, cl_fp, cl_estd, cl_fstd, cl_estde, cl_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {cl_fp}, with \n average extinction time {cl_et} with std {cl_estd} and std error {cl_estde} and \n average fixation time {cl_ft} with std {cl_fstd} and std error {cl_fstde}')
# Out:
# Fixation probability on 1000000 simulations is 0.009164, with
#  average extinction time 8.652200767836453 with std 36.1720350228182 and std error 0.0363389231896428 and
#  average fixation time 1895.9495853339154 with std 188.084572606358 and std error 6.276860146863689

# %%
params = ['Star', 'Wm', 'Clique']

star_ft, wm_ft, cl_ft = 1857.4050913115661, 1899.9731279872544, 1895.9495853339154
star_fstde, wm_fstde, cl_fstde = 5.773043365670133, 4.464500877653584, 6.276860146863689

mean = np.array([star_ft, wm_ft, cl_ft])
error = np.array([star_fstde, wm_fstde, cl_fstde])*1.96


plt.errorbar(mean,np.array(range(len(mean))), xerr=error, linewidth=1, linestyle='none', marker='o', markersize=3, markeredgecolor='black', capsize=5)
#plt.axvline(0, color = 'k', ls = '--')
plt.yticks(range(len(params)), params)
plt.title('Fixation time, 95% confidence intervals (leaf)')
plt.xlabel('Time')
#plt.savefig('fixation leaf.pdf')
plt.show()

# %%
params = ['Star', 'Wm', 'Clique']

star_et, wm_et, cl_et = 8.900208382738038, 8.619522807230071,8.652200767836453
star_estde, wm_estde, cl_estde = 0.03653358789430927, 0.03616848483339814, 0.0363389231896428

mean = np.array([star_et, wm_et, cl_et])
error = np.array([star_estde, wm_estde, cl_estde])*1.96


plt.errorbar(mean,np.array(range(len(mean))), xerr=error, linewidth=1, linestyle='none', marker='o', markersize=3, markeredgecolor='black', capsize=5)
#plt.axvline(0, color = 'k', ls = '--')
plt.yticks(range(len(params)), params)
plt.title('Extinction time, 95% confidence intervals (leaf)')
plt.xlabel('Time')
plt.savefig('extinction leaf.pdf')
plt.show()

# %% [markdown]
# ### Center mutant

# %%
#Initial state for the star
in_numbers=np.array([[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder=None

# %%
#Migration matrix of the star
migration_matrix=define_star(N_demes,mI,mO, equal_contribution=True)

# %%
#Fixation probability 
nb_sim=1000000
star_et, star_ft, star_fp, star_estd, star_fstd, star_estde, star_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {star_fp}, with \n average extinction time {star_et} with std {star_estd} and std error {star_estde} and \n average fixation time {star_ft} with std {star_fstd} and std error {star_fstde}')
# Out:
# Fixation probability on 1000000 simulations is 0.003163, with
#  average extinction time 4.509819559265958 with std 22.305324745193342 and std error 0.022340684520650186 and
#  average fixation time 1861.9709136895353 with std 112.21827755888623 and std error 1.9953266469839361

# %%
#Migration matrix of the clique
migration_matrix=define_clique(N_demes,m)

# %%
cl_et, cl_ft, cl_fp, cl_estd, cl_fstd, cl_estde, cl_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=False)
print(f'Fixation probability on {nb_sim} simulations is {cl_fp}, with \n average extinction time {cl_et} with std {cl_estd} and std error {cl_estde} and \n average fixation time {cl_ft} with std {cl_fstd} and std error {cl_fstde}')
# Out:
# Fixation probability on 1000000 simulations is 0.00913, with
#  average extinction time 8.65369019144792 with std 35.87739280052524 and std error 0.03604230318561726 and
#  average fixation time 1904.1132530120483 with std 192.18771272645444 and std error 2.0113619467775603

# %%
params = ['Star', 'Wm', 'Clique']

wm_ft = 1895.9495853339154
wm_fstde = 4.464500877653584

mean = np.array([star_ft, wm_ft, cl_ft])
error = np.array([star_fstde, wm_fstde, cl_fstde])*1.96


plt.errorbar(mean,np.array(range(len(mean))), xerr=error, linewidth=1, linestyle='none', marker='o', markersize=3, markeredgecolor='black', capsize=5)
#plt.axvline(0, color = 'k', ls = '--')
plt.yticks(range(len(params)), params)
plt.title('Fixation time, 95% confidence intervals (center)')
plt.xlabel('Time')
plt.show()

# %%
params = ['Star', 'Wm', 'Clique']

wm_et = 8.619522807230071
wm_estde = 0.03616848483339814 

mean = np.array([star_et, wm_et, cl_et])
error = np.array([star_estde, wm_estde, cl_estde])*1.96


plt.errorbar(mean,np.array(range(len(mean))), xerr=error, linewidth=1, linestyle='none', marker='o', markersize=3, markeredgecolor='black', capsize=5)
#plt.axvline(0, color = 'k', ls = '--')
plt.yticks(range(len(params)), params)
plt.title('Extinction time, 95% confidence intervals (center)')
plt.xlabel('Time')
plt.show()

# %%
Nc = ((N_demes-1)*mI + (1-(N_demes-1)*mO))*K
Nl = (mO+1-mI)*K

# %%
params = ['Star', 'Wm', 'Clique']

star_ft_average = (star_ft * Nc + 1857.4050913115661 * (N_demes-1)*Nl)/(K*N_demes)
cl_ft_average = (cl_ft * Nc + 1895.9495853339154 * (N_demes-1)*Nl)/(K*N_demes)

mean = np.array([star_ft_average, wm_ft, cl_ft_average])


plt.plot(mean,np.array(range(len(mean))), linewidth=1, linestyle='none', marker='o', markersize=6, markeredgecolor='black')
plt.yticks(range(len(params)), params)
plt.title('Fixation time (averaged)')
plt.xlabel('Time')
plt.show()

# %%
params = ['Star', 'Wm', 'Clique']

star_et_average = (star_et * Nc + 8.900208382738038 * (N_demes-1)*Nl)/(K*N_demes)
cl_et_average = (cl_et * Nc + 8.652200767836453 * (N_demes-1)*Nl)/(K*N_demes)

mean = np.array([star_et_average, wm_et, cl_et_average])


plt.plot(mean,np.array(range(len(mean))), linewidth=1, linestyle='none', marker='o', markersize=6, markeredgecolor='black')
plt.yticks(range(len(params)), params)
plt.title('Extinction time (averaged)')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# ### Save some dynamics

# %% [markdown]
# Let's same around 1000 trajectories for extinction and fixation in the configurations: well-mixed, clique and star.

# %% [markdown]
# - Star, leaf

# %%
#Initial state for the star
in_numbers=np.array([[0.,1000.],[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder='Test5/Leaf/Star'

#Migration matrix of the star
migration_matrix=define_star(N_demes,mI,mO, equal_contribution=True)

# %%
#Fixation probability 
nb_sim=200000
star_et, star_ft, star_fp, star_estd, star_fstd, star_estde, star_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=True)
print(f'Fixation probability on {nb_sim} simulations is {star_fp}, with \n average extinction time {star_et} with std {star_estd} and std error {star_estde} and \n average fixation time {star_ft} with std {star_fstd} and std error {star_fstde}')
# Out:
# Fixation probability on 200000 simulations is 0.009105, with
#  average extinction time 8.808006902850453 with std 35.70461032399051 and std error 0.08020389897319628 and
#  average fixation time 1853.6018671059858 with std 142.87133000995505 and std error 3.348035966332804

# %% [markdown]
# - Star, center

# %%
#Initial state for the star
in_numbers=np.array([[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder='Test5/Center/Star'

#Migration matrix of the star
migration_matrix=define_star(N_demes,mI,mO, equal_contribution=True)

# %%
#Fixation probability 
star_et, star_ft, star_fp, star_estd, star_fstd, star_estde, star_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=True)
print(f'Fixation probability on {nb_sim} simulations is {star_fp}, with \n average extinction time {star_et} with std {star_estd} and std error {star_estde} and \n average fixation time {star_ft} with std {star_fstd} and std error {star_fstde}')
# Out:
# Fixation probability on 200000 simulations is 0.00318, with
#  average extinction time 4.618762665275576 with std 23.894773981747075 and std error 0.05351549632336887 and
#  average fixation time 1846.7264150943397 with std 152.00094902567906 and std error 6.0272296827738785

# %% [markdown]
# - Clique, leaf

# %%
in_numbers=np.array([[0.,1000.],[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
    
#Parameters
m=0.05
mO=m/2
mI=4*mO
s=0.001
fitnesses=np.array([1+s,1])
nb_cycles=2500
t=np.log(100)
N_demes=5
K=1000
folder='Test5/Leaf/Clique'
migration_matrix=define_clique(N_demes,m)

# %%
#Fixation probability 
cl_et, cl_ft, cl_fp, cl_estd, cl_fstd, cl_estde, cl_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=True)
print(f'Fixation probability on {nb_sim} simulations is {cl_fp}, with \n average extinction time {cl_et} with std {cl_estd} and std error {cl_estde} and \n average fixation time {cl_ft} with std {cl_fstd} and std error {cl_fstde}')
# Out:
# Fixation probability on 200000 simulations is 0.00916, with
#  average extinction time 8.701626902426224 with std 36.36979076652023 and std error 0.08170037302686753 and
#  average fixation time 1894.0545851528384 with std 174.73366230849226 and std error 4.082383921751267

# %% [markdown]
# - Clique, center

# %%
#Initial state for the star
in_numbers=np.array([[1.,999.],[0.,1000.],[0.,1000.],[0.,1000.],[0.,1000.]]).astype(np.int64)
folder='Test5/Center/Clique'

#Fixation probability 
cl_et, cl_ft, cl_fp, cl_estd, cl_fstd, cl_estde, cl_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=True)
print(f'Fixation probability on {nb_sim} simulations is {cl_fp}, with \n average extinction time {cl_et} with std {cl_estd} and std error {cl_estde} and \n average fixation time {cl_ft} with std {cl_fstd} and std error {cl_fstde}')
# Out:
# Fixation probability on 200000 simulations is 0.008965, with
#  average extinction time 8.67199947529603 with std 36.25406292562566 and std error 0.08143239164827354 and
#  average fixation time 1896.5588399330732 with std 178.63628854957994 and std error 4.218708735471078

# %% [markdown]
# - Well-mixed

# %%
#Migration matrix of the clique
migration_matrix=np.array([[1]])
in_numbers=np.array([[1.,4999.]]).astype(np.int64)

#Fixation probability 
K=5000
wm_et, wm_ft, wm_fp, wm_estd, wm_fstd, wm_estde, wm_fstde = fixation_probability_stat(in_numbers, folder, migration_matrix, fitnesses, nb_sim, nb_cycles, t, K, size_follow_numbers=2500, print_frequency=1, save_dynamics=True)
print(f'Fixation probability on {nb_sim} simulations is {wm_fp}, with \n average extinction time {wm_et} with std {wm_estd} and std error {wm_estde} and \n average fixation time {wm_ft} with std {wm_fstd} and std error {wm_fstde}')
